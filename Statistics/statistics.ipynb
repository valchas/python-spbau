# %%
import pandas
import matplotlib.pyplot as plt
from scipy import stats

df1 = pandas.read_csv("water.csv")

df1['water'].plot(kind='bar')

df1 = pandas.DataFrame(data={'df1': df1['water'],})

df1.plot.kde()

d1 = df1['df1']

print(stats.kstest(d1, 'norm', (d1.mean(), d1.std()), N=5000))
# Out:
# KstestResult(statistic=0.10168855544914623, pvalue=0.9582867025010181)
